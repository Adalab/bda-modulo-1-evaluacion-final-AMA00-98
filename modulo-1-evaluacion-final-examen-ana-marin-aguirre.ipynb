# %%
# Ejercicio IMPORTANTE --> Class TiendaOnline 

class TiendaOnline: 

    def __init__(self):
        self.inventario = [] 
        self.ventas_totales = 0.0 
    
    def agregar_producto(self, nombre, precio, cantidad): 
        for p in self.inventario:
            if p["nombre"] == nombre:
                p["cantidad"] += cantidad #
                return #       
        producto_nuevo = {}
        producto_nuevo.update({"nombre": nombre, "precio": precio, "cantidad": cantidad})
        self.inventario.append(producto_nuevo) #
    
    def ver_inventario(self): 
        for i in self.inventario:
            print(f"nombre: {i['nombre']}, precio: {i['precio']}, cantidad: {i['cantidad']}")
    
    def buscar_producto(self, nombre):
        for p in self.inventario:
            if p["nombre"ArithmeticError] == nombre:
                print(f"nombre: {p['nombre']}, precio: {p['precio']}, cantidad: {p['cantidad']}") #
    
    def actualizar_stock(self, nombre, cantidad):
        for s in self.inventario:
            if s["nombre"] == nombre:
                s["cantidad"] += cantidad #
                return #
        print("El producto no está en el inventario")
    
    def eliminar_producto(self, nombre):
        for p in self.inventario:
            if p["nombre"] == nombre:
                self.inventario.remove(p)
                return #
        print("El producto no está en el inventario")
    
    def calcular_valor_inventario(self):
        for v in self.inventario:
            valor_producto = v['precio'] * v['cantidad']
            self.ventas_totales += valor_producto
        return self.ventas_totales #

# %%
tienda_examen = TiendaOnline()

# %%
tienda_examen.__dict__
# Out:
# {'inventario': [], 'ventas_totales': 0.0}

# %%
# --------- PRUEBAS ----------

# def agregar_producto(self, nombre, precio, cantidad): 

tienda_examen.agregar_producto("patata", 2.5, 50)
tienda_examen.agregar_producto("patata", 2.5, 5)
tienda_examen.agregar_producto("manzana", 2, 25)
tienda_examen.agregar_producto("manzana", 2, 10)
tienda_examen.agregar_producto("lechuga", 3, 30)
print("-----------------------------------------------------------")

# def ver_inventario(self):

tienda_examen.ver_inventario()
print("-----------------------------------------------------------")

# def buscar_producto(self, nombre):

tienda_examen.buscar_producto("manzana")
print("-----------------------------------------------------------")

# def actualizar_stock(self, nombre, cantidad):

tienda_examen.actualizar_stock("patata", 5)
tienda_examen.actualizar_stock("lechuga", 10)
tienda_examen.actualizar_stock("tomate", 20)
print("-----------------------------------------------------------")

#  def eliminar_producto(self, nombre):

tienda_examen.eliminar_producto("lechuga")
tienda_examen.eliminar_producto("cebolla")

#  def calcular_valor_inventario(self):

tienda_examen.calcular_valor_inventario()
print("-----------------------------------------------------------")
# Out:
# -----------------------------------------------------------
# nombre: patata, precio: 2.5, cantidad: 55
# nombre: manzana, precio: 2, cantidad: 35
# nombre: lechuga, precio: 3, cantidad: 30
# -----------------------------------------------------------
# nombre: manzana, precio: 2, cantidad: 35
# -----------------------------------------------------------
# El producto no está en el inventario
# -----------------------------------------------------------
# El producto no está en el inventario
# -----------------------------------------------------------

# %%
class TiendaOnline: 

    def __init__(self):
        self.inventario = [{"nombre": "patata", "precio": 2.5, "cantidad": 55}, {"nombre": "manzana", "precio": 2, "cantidad": 35}, {"nombre": "lechuga", "precio": 3, "cantidad": 30}] 
        self.ventas_totales = 0.0 
    
    def calcular_valor_inventario(self):
        for v in self.inventario:
            valor_producto = v["precio"] * v["cantidad"]
            self.ventas_totales = SUMA(valor_producto)
        return self.ventas_totales

# %%
tienda_examen2 = TiendaOnline()

# %%
tienda_examen2.__dict__
# Out:
# {'inventario': [{'nombre': 'patata', 'precio': 2.5, 'cantidad': 55},
#   {'nombre': 'manzana', 'precio': 2, 'cantidad': 35},
#   {'nombre': 'lechuga', 'precio': 3, 'cantidad': 30}],
#  'ventas_totales': 0.0}

# %%
tienda_examen2.calcular_valor_inventario()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[297], line 1
# ----> 1 tienda_examen2.calcular_valor_inventario()
#
# Cell In[294], line 10, in TiendaOnline.calcular_valor_inventario(self)
#       8 for v in self.inventario:
#       9     valor_producto = v["precio"] * v["cantidad"]
# ---> 10     self.ventas_totales = SUMA(valor_producto)
#      11 return self.ventas_totales
#
# NameError: name 'SUMA' is not defined
